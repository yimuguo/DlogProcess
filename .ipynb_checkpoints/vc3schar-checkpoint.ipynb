# %%
from dlogprocess.char.char_dlog import CharDlog
from collections import Counter
import pandas as pd

# %%
vc3schar = CharDlog(r'./dlogprocess/Data/Char/Room_30X.txt', '25C')

# %%
data = vc3schar.gen_df()

# %%
tests = list(Counter(data.Test).keys())

# %%
pins = list(Counter(data.Pin).keys())

# %%
data = data.convert_objects(convert_numeric=True)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
data.dtypes
# Out:
# VDD        float64
# Test        object
# Pin         object
# Data       float64
# unit        object
# Force      float64
# Lot         object
# Temp        object
# UnitNum      int64
# dtype: object

# %%
def get_summary(vddmin, vddmax, data):
    _df = []
    for x in tests:
        for y in pins:
            if not(data[(data.Test == x) & (data.Pin == y) & (data.VDD > vddmin) & (data.VDD < vddmax)].Data.empty):
    #             print(data[(data.Test == x) & (data.Pin == y)].Data.describe())
                _dfbuffer = list(data[(data.Test == x) & (data.Pin == y) & (data.VDD > vddmin) & (data.VDD < vddmax)].Data.describe())[1:]
                _dfbuffer.insert(0, y)
                _dfbuffer.insert(0, x)
                _df.append(_dfbuffer)
    df = pd.DataFrame(_df, columns = ['Test', 'Pin', 'mean', 'std', 'min', '_25p', '_50p', '_75p', 'max'])
    return df

# %%
sum33 = get_summary(3.3*0.85, 3.3*1.15, data)
sum33.to_csv('sum33.csv')
sum25 = get_summary(2.5*0.85, 2.5*1.15, data)
sum25.to_csv('sum25.csv')
sum18 = get_summary(1.8*0.85, 1.8*1.15, data)
sum18.to_csv('sum18.csv')

# %%
sum33
# Out:
#                Test       Pin       mean           std       min        _25p  \
# 0       IDD_Default  VDDSE2_3  18.080917  1.290775e+00   16.1200   17.092500
# 1       IDD_Default      VDDA  40.768000  5.970634e-01   39.7600   40.287500
# 2       IDD_Default    VDDSE1   0.036796  1.238757e-02    0.0230    0.027000
# 3       IDD_Default      VBAT   0.012062  3.897249e-03   -0.0080    0.011000
# 4       IDD_Default     VDD33   8.580558  3.757817e-01    7.9300    8.249750
# 5     OutputLeakage     DIFF1  12.872003  2.296743e+01  -11.2865   -9.618500
# 6     OutputLeakage    DIFF2B   5.977512  1.004374e+01   -5.4484   -3.988900
# 7     OutputLeakage       SE1   3.128000  7.630084e+00   -6.2824   -4.614400
# 8     OutputLeakage       REF  -1.681452  6.125773e+00   -9.6185   -7.950400
# 9     OutputLeakage       SE3 -86.508238  2.244290e+02 -444.3495 -112.671675
# 10    OutputLeakage       SE2  27.963823  1.101230e+02  -12.1205  -10.452500
# 11    OutputLeakage    DIFF1B  30.181030  8.359077e+01    1.2237    2.057700
# 12    OutputLeakage     DIFF2   3.308693  2.583058e+01  -24.6306  -22.128600
# 13   IDDLVPECL_500M      VDDA  49.359875  1.603595e+00   46.9300   48.125000
# 14         thd:DATA       SMB  -0.148917  1.830910e-02   -0.2300   -0.150000
# 15           IDD_SD  VDDSE2_3   0.010175  1.966934e-03    0.0050    0.009000
# 16           IDD_SD      VDDA   2.478563  3.263998e-02    2.4300    2.451750
# 17           IDD_SD    VDDSE1   0.027854  2.321354e-03    0.0220    0.026000
# 18           IDD_SD      VBAT   0.143804  3.016106e-01    0.0090    0.013000
# 19           IDD_SD     VDD33   1.018096  2.619406e-02    0.9780    0.997000
# 20     IDDLVDS_500M      VDDA  54.172208  1.548976e+00   51.8200   52.980000
# 21          VCO_max      PLL2   1.600000  6.775215e-16    1.6000    1.600000
# 22          VCO_max      PLL3   1.330000  1.129203e-15    1.3300    1.330000
# 23          VCO_max      PLL1   0.920000  6.775215e-16    0.9200    0.920000
# 24              VOL       DF2   0.246475  7.356394e-03    0.2360    0.240500
# 25              VOL      DF1B   0.590658  3.176166e-02    0.5490    0.564250
# 26              VOL      DF2B   0.609058  3.184344e-02    0.5670    0.583000
# 27              VOL    SDA4mA   0.229583  2.462763e-02    0.2000    0.200000
# 28              VOL       SE1   0.286088  8.960434e-03    0.2740    0.278500
# 29              VOL       REF   0.276233  9.199084e-03    0.2630    0.268500
# ..              ...       ...        ...           ...       ...         ...
# 75              VIH       OE2   1.671250  1.199132e-01    1.4500    1.550000
# 76              VIH  SCL_DFC1   1.256042  9.536847e-02    1.1000    1.187500
# 77     IDDLVDS_250M      VDDA  45.641917  8.562283e-01   44.3200   44.975000
# 78     IDDCore_PLL3     VDD33   5.450250  2.850014e+00    2.3810    2.588750
# 79         tsu:DATA       SMB   0.019167  4.004878e-03    0.0000    0.020000
# 80     InputLeakage  SDA_DFC0  23.335310  5.389379e+01  -10.4525   -7.950400
# 81     InputLeakage       OE1  17.544517  1.471031e-02   17.5181   17.534800
# 82     InputLeakage       OE3  -6.917463  2.479758e+01  -33.8047  -31.302700
# 83     InputLeakage        X1   0.039060  1.975495e+01  -19.5787  -19.553600
# 84     InputLeakage       OE2 -15.726970  3.380043e+01  -51.3190  -49.025400
# 85     InputLeakage  SCL_DFC1  -8.179927  8.218414e+01 -444.3495   -2.946400
# 86              ROL       DF2   0.596654  3.155989e-02    0.5550    0.571000
# 87              ROL      DF1B   0.245654  7.480042e-03    0.2350    0.239500
# 88              ROL      DF2B   0.253883  7.542552e-03    0.2430    0.247000
# 89              ROL       SE1   0.712929  4.638513e-02    0.6540    0.675250
# 90              ROL       REF   0.692704  4.686435e-02    0.6330    0.655000
# 91              ROL       SE3   0.691688  4.512204e-02    0.6340    0.655250
# 92              ROL       SE2   0.690446  4.592131e-02    0.6320    0.653250
# 93              ROL       DF1   0.571633  3.118428e-02    0.5300    0.546000
# 94   IDDLPHCSL_100M      VDDA  40.692208  5.623342e-01   39.7400   40.255000
# 95              VIL  SDA_DFC0   1.557083  1.081986e-01    1.3500    1.450000
# 96              VIL       SDA   1.206667  9.636344e-02    1.0500    1.150000
# 97              VIL       OE1   1.325417  1.147119e-01    1.1500    1.237500
# 98              VIL       OE3   1.321875  1.030428e-01    1.1500    1.250000
# 99              VIL       SCL   1.192708  9.560947e-02    1.0500    1.100000
# 100             VIL        X1   1.300000  7.515674e-02    1.2000    1.237500
# 101             VIL       OE2   1.336667  1.015020e-01    1.1500    1.250000
# 102             VIL  SCL_DFC1   1.552917  1.063459e-01    1.3500    1.450000
# 103    IDDLVDS_125M      VDDA  40.400792  4.028982e-01   39.6400   39.990000
# 104    IDDCMOS_160M    VDDSE1   3.712529  4.359742e-01    3.0100    3.303750
#
#          _50p       _75p       max
# 0    18.07500  19.067500   20.0600
# 1    40.79000  41.245000   41.7600
# 2     0.03100   0.044750    0.0660
# 3     0.01200   0.013000    0.0280
# 4     8.58050   8.888750    9.1570
# 5     7.89575  36.252100   40.4221
# 6     5.39370  16.235800   18.7379
# 7     3.30870  10.397800   12.8998
# 8    -1.27835   3.934200    6.2277
# 9     9.98080  11.231800  389.6603
# 10   -3.78035   1.223700  389.6603
# 11   17.90390  19.571900  389.6603
# 12   -1.69540  29.580000   34.5841
# 13   49.33500  50.572500   51.8400
# 14   -0.15000  -0.130000   -0.1100
# 15    0.01000   0.011000    0.0170
# 16    2.47650   2.503500    2.5340
# 17    0.02800   0.030000    0.0340
# 18    0.02900   0.056500    0.9690
# 19    1.01550   1.037250    1.0660
# 20   54.15000  55.345000   56.5700
# 21    1.60000   1.600000    1.6000
# 22    1.33000   1.330000    1.3300
# 23    0.92000   0.920000    0.9200
# 24    0.24500   0.251750    0.2600
# 25    0.58500   0.611250    0.6480
# 26    0.60300   0.630000    0.6660
# 27    0.25000   0.250000    0.2500
# 28    0.28450   0.292250    0.3020
# 29    0.27500   0.283000    0.2930
# ..        ...        ...       ...
# 75    1.67500   1.762500    1.8500
# 76    1.25000   1.350000    1.4000
# 77   45.63000  46.295000   46.9700
# 78    5.35100   8.270000    9.0980
# 79    0.02000   0.020000    0.0200
# 80   34.16705  38.754100  389.6603
# 81   17.54310  17.551500   17.5932
# 82   -5.57875  17.661975   17.7016
# 83    0.03725  19.628100   19.6698
# 84  -13.86465  17.776600   17.8100
# 85    6.22770  15.401800   17.9039
# 86    0.59100   0.617000    0.6540
# 87    0.24450   0.250750    0.2590
# 88    0.25300   0.258750    0.2670
# 89    0.70350   0.742250    0.7980
# 90    0.68300   0.722500    0.7790
# 91    0.68250   0.720250    0.7740
# 92    0.68100   0.719250    0.7750
# 93    0.56550   0.592750    0.6280
# 94   40.74500  41.200000   41.7200
# 95    1.55000   1.650000    1.7500
# 96    1.20000   1.300000    1.3500
# 97    1.35000   1.412500    1.5000
# 98    1.32500   1.400000    1.5000
# 99    1.20000   1.262500    1.3500
# 100   1.30000   1.362500    1.4000
# 101   1.32500   1.412500    1.5000
# 102   1.55000   1.650000    1.7500
# 103  40.33500  40.690000   41.0300
# 104   3.63250   4.016000    4.5300
#
# [105 rows x 9 columns]

# %%
sum33['Temp'] = '25C'
