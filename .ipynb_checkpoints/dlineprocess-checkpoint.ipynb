# %%
# %matplotlib inline
from delay_char import DlyLineDlog
import sys
import os
import numpy as np
import pandas as pd
import matplotlib

# %%
def data2df(lot_num, temp):
    dly = DlyLineDlog(os.path.join(".\\data\\Delay_line\\", lot_num, temp, "summary_" + temp + '.txt'), temp, lot_num)
    df_lst = dly.gen_df_lst()
    return  pd.DataFrame(df_lst)

# %%
lotnum = "RC01927M"
temp = '25C'
df = data2df(lotnum, temp)
df = df.append(data2df(lotnum, '105C'))
df = df.append(data2df(lotnum, '-5C'))
lotnum = "RC01928M"
df = df.append(data2df(lotnum, '25C'))
df = df.append(data2df(lotnum, '105C'))
df = df.append(data2df(lotnum, '-5C'))

lotnum = "RC01929M"
df = df.append(data2df(lotnum, '25C'))
df = df.append(data2df(lotnum, '105C'))
df = df.append(data2df(lotnum, '-5C'))

# %%
df.columns = ['Lot', 'Temp', 'Dev#', 'VDD', 'Test', 'Data0', 'Data1']

# %%
def slice_unit(dev_num, lot_num, data_frame):
    df = df[(df['Dev#'] != dev_num) | (df['Lot'] != lot_num)]

# %%
# df[(df['Test'] == 'VOH') | (df['Test'] == 'VOL')]

# %%
df.loc[df.Test == 'Delay', 'Data1'] = df[df.Test == 'Delay'].Data1.astype(int)

# %%
# df_delay["Data1"] = df_delay['Data1'].convert_objects(convert_numeric=True)

# %%
df[(df['Test'] == 'IDD') & (df['Data0'] > 4.5)].head(5)
# Out:
#            Lot Temp  Dev#  VDD Test  Data0    Data1
# 2160  RC01927M  -5C     2  3.7  IDD  5.507   STATIC
# 2161  RC01927M  -5C     2  3.7  IDD  5.559  DYNAMIC
# 2162  RC01927M  -5C     2  3.6  IDD  5.421   STATIC
# 2163  RC01927M  -5C     2  3.6  IDD  5.431  DYNAMIC
# 2164  RC01927M  -5C     2  3.5  IDD  5.380   STATIC

# %%
df.loc[df.Test == 'Delay', 'Dly'] = df[df.Test == 'Delay'].apply(lambda x: (x['Data0'] * 1000 - int(x['Data1'])) / int(x['Data1']) * 100, axis=1)

# %%
df_dly = df[df.Test == 'Delay']

# %%
df_dly[df_dly['Data1'] < 8000]['Dly'].describe()
# Out:
# count    86400.000000
# mean         0.962419
# std          1.339775
# min         -3.500000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          4.500000
# Name: Dly, dtype: float64

# %%
df_dly[df_dly['Data1'] > 8000]['Dly'].plot(kind='hist', alpha=0.5)

# %%
df_dly[df_dly['Data1'] >= 8000].Dly.describe()
# Out:
# count    131760.000000
# mean          0.528639
# std           0.741932
# min          -2.000000
# 25%           0.000000
# 50%           0.597938
# 75%           1.000000
# max           3.000000
# Name: Dly, dtype: float64

# %%
df_dly[df_dly.index == [df_dly[(df_dly.Data1 >= 8000)].Dly.argmax()]]
# Out:
#            Lot  Temp  Dev#  VDD   Test  Data0 Data1  Dly
# 9128  RC01927M   25C     9  2.9  Delay   8.04  8000  0.5
# 9128  RC01927M  105C    10  2.9  Delay   8.08  8000  1.0
# 9128  RC01927M   -5C    11  2.9  Delay   8.08  8000  1.0
# 9128  RC01929M   25C     9  2.9  Delay   8.16  8000  2.0
# 9128  RC01929M  105C     9  2.9  Delay   8.24  8000  3.0
# 9128  RC01929M   -5C     9  2.9  Delay   8.16  8000  2.0

# %%
df_dly[df_dly.index == [df_dly[(df_dly.Data1 < 8000)].Dly.argmax()]]
# Out:
#             Lot  Temp  Dev#  VDD   Test  Data0 Data1  Dly
# 14177  RC01927M   25C    14  3.0  Delay   2.00  2000  0.0
# 14177  RC01927M  105C    15  3.0  Delay   2.02  2000  1.0
# 14177  RC01927M   -5C    16  3.0  Delay   2.00  2000  0.0
# 14177  RC01928M   25C    16  3.0  Delay   2.07  2000  3.5
# 14177  RC01928M  105C    14  3.0  Delay   2.09  2000  4.5
# 14177  RC01928M   -5C    14  3.0  Delay   2.08  2000  4.0
# 14177  RC01929M   25C    14  3.0  Delay   2.01  2000  0.5
# 14177  RC01929M  105C    14  3.0  Delay   2.01  2000  0.5
# 14177  RC01929M   -5C    14  3.0  Delay   2.01  2000  0.5

# %%
df_dly[(df_dly.Temp == '25C') & (df_dly['Dev#'] == 16) & (df_dly.Lot == 'RC01929M')]
# Out:
#             Lot Temp  Dev#  VDD   Test    Data0  Data1      Dly
# 16350  RC01929M  25C    16  3.7  Delay   2.0500   2000  2.50000
# 16351  RC01929M  25C    16  3.6  Delay   2.0500   2000  2.50000
# 16352  RC01929M  25C    16  3.5  Delay   2.0500   2000  2.50000
# 16353  RC01929M  25C    16  3.4  Delay   2.0400   2000  2.00000
# 16354  RC01929M  25C    16  3.3  Delay   2.0500   2000  2.50000
# 16355  RC01929M  25C    16  3.2  Delay   2.0500   2000  2.50000
# 16356  RC01929M  25C    16  3.1  Delay   2.0700   2000  3.50000
# 16357  RC01929M  25C    16  3.0  Delay   2.0600   2000  3.00000
# 16358  RC01929M  25C    16  2.9  Delay   2.0600   2000  3.00000
# 16359  RC01929M  25C    16  2.8  Delay   2.0700   2000  3.50000
# 16360  RC01929M  25C    16  3.7  Delay   2.1525   2100  2.50000
# 16361  RC01929M  25C    16  3.6  Delay   2.1420   2100  2.00000
# 16362  RC01929M  25C    16  3.5  Delay   2.1525   2100  2.50000
# 16363  RC01929M  25C    16  3.4  Delay   2.1315   2100  1.50000
# 16364  RC01929M  25C    16  3.3  Delay   2.1420   2100  2.00000
# 16365  RC01929M  25C    16  3.2  Delay   2.1525   2100  2.50000
# 16366  RC01929M  25C    16  3.1  Delay   2.1630   2100  3.00000
# 16367  RC01929M  25C    16  3.0  Delay   2.1630   2100  3.00000
# 16368  RC01929M  25C    16  2.9  Delay   2.1630   2100  3.00000
# 16369  RC01929M  25C    16  2.8  Delay   2.1630   2100  3.00000
# 16370  RC01929M  25C    16  3.7  Delay   2.2330   2200  1.50000
# 16371  RC01929M  25C    16  3.6  Delay   2.2330   2200  1.50000
# 16372  RC01929M  25C    16  3.5  Delay   2.2330   2200  1.50000
# 16373  RC01929M  25C    16  3.4  Delay   2.2440   2200  2.00000
# 16374  RC01929M  25C    16  3.3  Delay   2.2440   2200  2.00000
# 16375  RC01929M  25C    16  3.2  Delay   2.2440   2200  2.00000
# 16376  RC01929M  25C    16  3.1  Delay   2.2770   2200  3.50000
# 16377  RC01929M  25C    16  3.0  Delay   2.2770   2200  3.50000
# 16378  RC01929M  25C    16  2.9  Delay   2.2770   2200  3.50000
# 16379  RC01929M  25C    16  2.8  Delay   2.2770   2200  3.50000
# ...         ...  ...   ...  ...    ...      ...    ...      ...
# 17330  RC01929M  25C    16  3.7  Delay  19.7960  19600  1.00000
# 17331  RC01929M  25C    16  3.6  Delay  19.8350  19600  1.19898
# 17332  RC01929M  25C    16  3.5  Delay  19.7960  19600  1.00000
# 17333  RC01929M  25C    16  3.4  Delay  19.7960  19600  1.00000
# 17334  RC01929M  25C    16  3.3  Delay  19.7960  19600  1.00000
# 17335  RC01929M  25C    16  3.2  Delay  19.7960  19600  1.00000
# 17336  RC01929M  25C    16  3.1  Delay  19.8350  19600  1.19898
# 17337  RC01929M  25C    16  3.0  Delay  19.8350  19600  1.19898
# 17338  RC01929M  25C    16  2.9  Delay  19.8350  19600  1.19898
# 17339  RC01929M  25C    16  2.8  Delay  19.8350  19600  1.19898
# 17340  RC01929M  25C    16  3.7  Delay  19.9980  19800  1.00000
# 17341  RC01929M  25C    16  3.6  Delay  19.9980  19800  1.00000
# 17342  RC01929M  25C    16  3.5  Delay  19.9980  19800  1.00000
# 17343  RC01929M  25C    16  3.4  Delay  19.9980  19800  1.00000
# 17344  RC01929M  25C    16  3.3  Delay  19.9980  19800  1.00000
# 17345  RC01929M  25C    16  3.2  Delay  19.9980  19800  1.00000
# 17346  RC01929M  25C    16  3.1  Delay  20.0380  19800  1.20202
# 17347  RC01929M  25C    16  3.0  Delay  19.9980  19800  1.00000
# 17348  RC01929M  25C    16  2.9  Delay  20.0380  19800  1.20202
# 17349  RC01929M  25C    16  2.8  Delay  20.0380  19800  1.20202
# 17350  RC01929M  25C    16  3.7  Delay  20.2000  20000  1.00000
# 17351  RC01929M  25C    16  3.6  Delay  20.2000  20000  1.00000
# 17352  RC01929M  25C    16  3.5  Delay  20.2000  20000  1.00000
# 17353  RC01929M  25C    16  3.4  Delay  20.2000  20000  1.00000
# 17354  RC01929M  25C    16  3.3  Delay  20.2000  20000  1.00000
# 17355  RC01929M  25C    16  3.2  Delay  20.2000  20000  1.00000
# 17356  RC01929M  25C    16  3.1  Delay  20.2000  20000  1.00000
# 17357  RC01929M  25C    16  3.0  Delay  20.2400  20000  1.20000
# 17358  RC01929M  25C    16  2.9  Delay  20.2000  20000  1.00000
# 17359  RC01929M  25C    16  2.8  Delay  20.2400  20000  1.20000
#
# [1010 rows x 8 columns]
