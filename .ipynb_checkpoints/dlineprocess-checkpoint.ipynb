# %%
# %matplotlib inline
from delay_char import DlyLineDlog
import sys
import os
import numpy as np
import pandas as pd
import matplotlib

# %%
def data2df(lot_num, temp):
    dly = DlyLineDlog(os.path.join(".\\data\\Delay_line\\", lot_num, temp, "summary_" + temp + '.txt'), temp, lot_num)
    df_lst = dly.gen_df_lst()
    return  pd.DataFrame(df_lst)

# %%
lotnum = "RC01927M"
temp = '25C'
df = data2df(lotnum, temp)
df = df.append(data2df(lotnum, '105C'))
df = df.append(data2df(lotnum, '-5C'))
lotnum = "RC01928M"
df = df.append(data2df(lotnum, '25C'))
df = df.append(data2df(lotnum, '105C'))
df = df.append(data2df(lotnum, '-5C'))

# %%
df.shape
# Out:
# (160230, 7)

# %%
df.columns = ['LOT_Num', 'Temp', 'Dev#', 'VDD', 'Test', 'Data0', 'Data1']

# %%
df[(df['Test'] == 'VOH') | (df['Test'] == 'VOL')]
# Out:
#         LOT_Num Temp  Dev#   VDD Test  Data0 Data1
# 1030   RC01927M  25C     1  3.70  VOL  0.254  10mA
# 1031   RC01927M  25C     1  3.70  VOL  0.029   1mA
# 1032   RC01927M  25C     1  3.60  VOL  0.254  10mA
# 1033   RC01927M  25C     1  3.60  VOL  0.029   1mA
# 1034   RC01927M  25C     1  3.50  VOL  0.255  10mA
# 1035   RC01927M  25C     1  3.50  VOL  0.029   1mA
# 1036   RC01927M  25C     1  3.40  VOL  0.256  10mA
# 1037   RC01927M  25C     1  3.40  VOL  0.029   1mA
# 1038   RC01927M  25C     1  3.30  VOL  0.257  10mA
# 1039   RC01927M  25C     1  3.30  VOL  0.029   1mA
# 1040   RC01927M  25C     1  3.20  VOL  0.258  10mA
# 1041   RC01927M  25C     1  3.20  VOL  0.029   1mA
# 1042   RC01927M  25C     1  3.10  VOL  0.259  10mA
# 1043   RC01927M  25C     1  3.10  VOL  0.029   1mA
# 1044   RC01927M  25C     1  3.00  VOL  0.260  10mA
# 1045   RC01927M  25C     1  3.00  VOL  0.030   1mA
# 1046   RC01927M  25C     1  2.90  VOL  0.261  10mA
# 1047   RC01927M  25C     1  2.90  VOL  0.030   1mA
# 1048   RC01927M  25C     1  2.80  VOL  0.262  10mA
# 1049   RC01927M  25C     1  2.80  VOL  0.030   1mA
# 1050   RC01927M  25C     1  3.70  VOH  3.463  10mA
# 1051   RC01927M  25C     1  3.70  VOH  3.675   1mA
# 1052   RC01927M  25C     1  3.60  VOH  3.362  10mA
# 1053   RC01927M  25C     1  3.60  VOH  3.575   1mA
# 1054   RC01927M  25C     1  3.50  VOH  3.261  10mA
# 1055   RC01927M  25C     1  3.50  VOH  3.475   1mA
# 1056   RC01927M  25C     1  3.40  VOH  3.160  10mA
# 1057   RC01927M  25C     1  3.40  VOH  3.375   1mA
# 1058   RC01927M  25C     1  3.30  VOH  3.056  10mA
# 1059   RC01927M  25C     1  3.30  VOH  3.273   1mA
# ...         ...  ...   ...   ...  ...    ...   ...
# 25020  RC01928M  -5C    24  3.20  VOL  0.254  10mA
# 25021  RC01928M  -5C    24  3.20  VOL  0.027   1mA
# 25022  RC01928M  -5C    24  3.10  VOL  0.255  10mA
# 25023  RC01928M  -5C    24  3.10  VOL  0.027   1mA
# 25024  RC01928M  -5C    24  3.00  VOL  0.255  10mA
# 25025  RC01928M  -5C    24  3.00  VOL  0.027   1mA
# 25026  RC01928M  -5C    24  2.90  VOL  0.257  10mA
# 25027  RC01928M  -5C    24  2.90  VOL  0.027   1mA
# 25028  RC01928M  -5C    24  2.80  VOL  0.258  10mA
# 25029  RC01928M  -5C    24  2.80  VOL  0.028   1mA
# 25030  RC01928M  -5C    24  3.70  VOH  3.461  10mA
# 25031  RC01928M  -5C    24  3.70  VOH  3.673   1mA
# 25032  RC01928M  -5C    24  3.60  VOH  3.361  10mA
# 25033  RC01928M  -5C    24  3.60  VOH  3.573   1mA
# 25034  RC01928M  -5C    24  3.50  VOH  3.259  10mA
# 25035  RC01928M  -5C    24  3.50  VOH  3.474   1mA
# 25036  RC01928M  -5C    24  3.40  VOH  3.159  10mA
# 25037  RC01928M  -5C    24  3.40  VOH  3.374   1mA
# 25038  RC01928M  -5C    24  3.30  VOH  3.058  10mA
# 25039  RC01928M  -5C    24  3.30  VOH  3.274   1mA
# 25040  RC01928M  -5C    24  3.20  VOH  2.956  10mA
# 25041  RC01928M  -5C    24  3.20  VOH  3.173   1mA
# 25042  RC01928M  -5C    24  3.10  VOH  2.855  10mA
# 25043  RC01928M  -5C    24  3.10  VOH  3.074   1mA
# 25044  RC01928M  -5C    24  3.00  VOH  2.753  10mA
# 25045  RC01928M  -5C    24  3.00  VOH  2.974   1mA
# 25046  RC01928M  -5C    24  2.90  VOH  2.652  10mA
# 25047  RC01928M  -5C    24  2.90  VOH  2.874   1mA
# 25048  RC01928M  -5C    24  2.80  VOH  2.551  10mA
# 25049  RC01928M  -5C    24  2.80  VOH  2.774   1mA
#
# [5880 rows x 7 columns]

# %%
df.dtypes
# Out:
# LOT_Num     object
# Temp        object
# Dev#         int64
# VDD         object
# Test        object
# Data0      float64
# Data1       object
# dtype: object

# %%
df_delay = df[df['Test'] == 'Delay']

# %%
# df_delay["Data1"] = df_delay['Data1'].convert_objects(convert_numeric=True)

# %%
df_delay["Data1"] = df_delay['Data1'].astype(int)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_delay["Delay_percent"] = df_delay.apply(lambda x: (x['Data0']*1000 - x['Data1']) / x['Data1'] * 100, axis=1)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_delay[df_delay['Data1'] <= 4000]['Delay_percent'].plot(kind='hist', alpha=0.5)

# %%
df_delay[df_delay['Data1'] <= 8000]['Delay_percent'].describe()
# Out:
# count    29520.000000
# mean         0.997798
# std          1.060444
# min         -2.500000
# 25%          0.500000
# 50%          1.000000
# 75%          1.500000
# max          4.000000
# Name: Delay_percent, dtype: float64

# %%
df_delay['Delay_percent'].argmax()
# Out:
# 9817

# %%
df_delay[df_delay['Data1'] >= 8000]['Delay_percent'].describe()
# Out:
# count    43920.000000
# mean         0.551033
# std          0.605022
# min         -1.401961
# 25%          0.197531
# 50%          0.598039
# 75%          1.000000
# max          2.500000
# Name: Delay_percent, dtype: float64

# %%
df_delay.loc[df_delay[df_delay['Data1'] >= 8000]['Delay_percent'].argmax()]
# Out:
#         LOT_Num  Temp  Dev#  VDD   Test  Data0  Data1  Delay_percent
# 10215  RC01927M   25C    10  3.2  Delay   8.04   8000            0.5
# 10215  RC01927M  105C    11  3.2  Delay   8.20   8000            2.5
# 10215  RC01927M   -5C    12  3.2  Delay   8.04   8000            0.5

# %%
df_delay = df_delay[(df_delay['Dev#'] != 9) & (df_delay['LOT_Num'] != 'RC01928M')]

# %%
df_delay.describe()
# Out:
#                Dev#         Data0         Data1  Delay_percent
# count  72720.000000  72720.000000  72720.000000   72720.000000
# mean      14.097222     10.271029  10207.920792       0.727274
# std        7.581388      5.562666   5532.600213       0.849351
# min        1.000000      1.960000   2000.000000      -2.500000
# 25%        7.750000      4.975000   5000.000000       0.197531
# 50%       14.500000     10.100000  10000.000000       0.601064
# 75%       20.250000     15.120000  15000.000000       1.200000
# max       28.000000     20.360000  20000.000000       4.000000

# %%
df_delay[df_delay['Data1'] <= 4000]['Delay_percent'].plot(kind='hist')

# %%
df_delay[df_delay['Data1'] >= 4000]['Delay_percent'].plot(kind='hist')

# %%
df_delay[df_delay['Data1'] >= 4000]['Delay_percent'].describe()
# Out:
# count    58320.000000
# mean         0.537532
# std          0.678554
# min         -2.500000
# 25%          0.000000
# 50%          0.500000
# 75%          1.000000
# max          3.500000
# Name: Delay_percent, dtype: float64

# %%
df_delay[(df_delay["LOT_Num"] == 'RC01928M')]
# Out:
# Empty DataFrame
# Columns: [LOT_Num, Temp, Dev#, VDD, Test, Data0, Data1, Delay_percent]
# Index: []

# %%
df_delay
# Out:
#         LOT_Num Temp  Dev#  VDD   Test    Data0  Data1  Delay_percent
# 0      RC01927M  25C     1  3.7  Delay   1.9900   2000       -0.50000
# 1      RC01927M  25C     1  3.6  Delay   1.9900   2000       -0.50000
# 2      RC01927M  25C     1  3.5  Delay   1.9900   2000       -0.50000
# 3      RC01927M  25C     1  3.4  Delay   1.9900   2000       -0.50000
# 4      RC01927M  25C     1  3.3  Delay   1.9900   2000       -0.50000
# 5      RC01927M  25C     1  3.2  Delay   1.9900   2000       -0.50000
# 6      RC01927M  25C     1  3.1  Delay   1.9900   2000       -0.50000
# 7      RC01927M  25C     1  3.0  Delay   1.9900   2000       -0.50000
# 8      RC01927M  25C     1  2.9  Delay   1.9900   2000       -0.50000
# 9      RC01927M  25C     1  2.8  Delay   1.9900   2000       -0.50000
# 10     RC01927M  25C     1  3.7  Delay   2.0895   2100       -0.50000
# 11     RC01927M  25C     1  3.6  Delay   2.0790   2100       -1.00000
# 12     RC01927M  25C     1  3.5  Delay   2.0790   2100       -1.00000
# 13     RC01927M  25C     1  3.4  Delay   2.0895   2100       -0.50000
# 14     RC01927M  25C     1  3.3  Delay   2.0790   2100       -1.00000
# 15     RC01927M  25C     1  3.2  Delay   2.0895   2100       -0.50000
# 16     RC01927M  25C     1  3.1  Delay   2.1000   2100        0.00000
# 17     RC01927M  25C     1  3.0  Delay   2.0895   2100       -0.50000
# 18     RC01927M  25C     1  2.9  Delay   2.0895   2100       -0.50000
# 19     RC01927M  25C     1  2.8  Delay   2.1000   2100        0.00000
# 20     RC01927M  25C     1  3.7  Delay   2.2000   2200        0.00000
# 21     RC01927M  25C     1  3.6  Delay   2.1780   2200       -1.00000
# 22     RC01927M  25C     1  3.5  Delay   2.2000   2200        0.00000
# 23     RC01927M  25C     1  3.4  Delay   2.1780   2200       -1.00000
# 24     RC01927M  25C     1  3.3  Delay   2.1780   2200       -1.00000
# 25     RC01927M  25C     1  3.2  Delay   2.2110   2200        0.50000
# 26     RC01927M  25C     1  3.1  Delay   2.2000   2200        0.00000
# 27     RC01927M  25C     1  3.0  Delay   2.2000   2200        0.00000
# 28     RC01927M  25C     1  2.9  Delay   2.2110   2200        0.50000
# 29     RC01927M  25C     1  2.8  Delay   2.2000   2200        0.00000
# ...         ...  ...   ...  ...    ...      ...    ...            ...
# 28230  RC01927M  -5C    28  3.7  Delay  19.6000  19600        0.00000
# 28231  RC01927M  -5C    28  3.6  Delay  19.6000  19600        0.00000
# 28232  RC01927M  -5C    28  3.5  Delay  19.6000  19600        0.00000
# 28233  RC01927M  -5C    28  3.4  Delay  19.5610  19600       -0.19898
# 28234  RC01927M  -5C    28  3.3  Delay  19.6000  19600        0.00000
# 28235  RC01927M  -5C    28  3.2  Delay  19.5610  19600       -0.19898
# 28236  RC01927M  -5C    28  3.1  Delay  19.5610  19600       -0.19898
# 28237  RC01927M  -5C    28  3.0  Delay  19.5610  19600       -0.19898
# 28238  RC01927M  -5C    28  2.9  Delay  19.5610  19600       -0.19898
# 28239  RC01927M  -5C    28  2.8  Delay  19.5610  19600       -0.19898
# 28240  RC01927M  -5C    28  3.7  Delay  19.8000  19800        0.00000
# 28241  RC01927M  -5C    28  3.6  Delay  19.8000  19800        0.00000
# 28242  RC01927M  -5C    28  3.5  Delay  19.8000  19800        0.00000
# 28243  RC01927M  -5C    28  3.4  Delay  19.8000  19800        0.00000
# 28244  RC01927M  -5C    28  3.3  Delay  19.8000  19800        0.00000
# 28245  RC01927M  -5C    28  3.2  Delay  19.7600  19800       -0.20202
# 28246  RC01927M  -5C    28  3.1  Delay  19.7600  19800       -0.20202
# 28247  RC01927M  -5C    28  3.0  Delay  19.7600  19800       -0.20202
# 28248  RC01927M  -5C    28  2.9  Delay  19.7600  19800       -0.20202
# 28249  RC01927M  -5C    28  2.8  Delay  19.7600  19800       -0.20202
# 28250  RC01927M  -5C    28  3.7  Delay  20.0000  20000        0.00000
# 28251  RC01927M  -5C    28  3.6  Delay  20.0000  20000        0.00000
# 28252  RC01927M  -5C    28  3.5  Delay  19.9600  20000       -0.20000
# 28253  RC01927M  -5C    28  3.4  Delay  20.0000  20000        0.00000
# 28254  RC01927M  -5C    28  3.3  Delay  19.9600  20000       -0.20000
# 28255  RC01927M  -5C    28  3.2  Delay  19.9600  20000       -0.20000
# 28256  RC01927M  -5C    28  3.1  Delay  19.9600  20000       -0.20000
# 28257  RC01927M  -5C    28  3.0  Delay  19.9600  20000       -0.20000
# 28258  RC01927M  -5C    28  2.9  Delay  19.9600  20000       -0.20000
# 28259  RC01927M  -5C    28  2.8  Delay  19.9200  20000       -0.40000
#
# [72720 rows x 8 columns]
